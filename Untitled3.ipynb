# %%
a= 'hai'
b=['a','e','i','o','u']
c=''
print([i for i in 'hai' if i not in('a','e','i','o','u')])
# Out:
# ['h']

# %%
a='data'
b=['a','e','i','o','u']
c=''
print([i for i in a if i in b])
# Out:
# ['a', 'a']

# %%
a=[10,11,50,34]
for i in a:
 b=a.index(i)
 c=i,(b)
 print(c)
# Out:
# (10, 0)
# (11, 1)
# (50, 2)
# (34, 3)

# %%
a=[]
for i in range(1,51):
  if i%2!=0 and i%3 !=0:
    a.append(i)
print(a)
# Out:
# [1, 5, 7, 11, 13, 17, 19, 23, 25, 29, 31, 35, 37, 41, 43, 47, 49]

# %%
a=3
b=[]
for i in range(a+1,71):
  if i%a==0:
    b.append(i)
print(min(b))
# Out:
# 6

# %%
a='145'
c=[]
h=1
import math
for i in a:
  b=math.factorial(int(i))
  c.append(b)
for i in c:
    h=h+i
    d=h-1
print(d)
if a==str(d):
  print(f'strong number')
else:
  print(f'not a strong number')
# Out:
# 145
# strong number

# %%
a='data'
for i in a:
  b=a.upper()
  c=a.lower()
print(b)
print(c)
# Out:
# DATA
# data

# %%
a='united states'
b=' '
c=''
for i in a:
  if i!=b:
    c=c+i
print(c)
# Out:
# unitedstates

# %%
a='iam maheshwari'
b=a.title()
c=b.split()
for i in c:
  d=i[-1].upper()
  print(i.replace(i[-1],d),end=' ')
# Out:
# IaM MaheshwarI

# %%
a='rupasri'
res=0
for i in a:
  res=res+1
print(res)
# Out:
# 7
